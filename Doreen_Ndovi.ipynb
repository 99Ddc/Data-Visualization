# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
path ="//content/TopRichestInWorld.csv"
richest=pd.read_csv(path)

# %%
richest.head()
# Out:
#                        Name          NetWorth  Age Country/Territory  \
# 0                 Elon Musk  $219,000,000,000   50     United States
# 1                Jeff Bezos  $171,000,000,000   58     United States
# 2  Bernard Arnault & family  $158,000,000,000   73            France
# 3                Bill Gates  $129,000,000,000   66     United States
# 4            Warren Buffett  $118,000,000,000   91     United States
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
plt.figure(figsize=(8,5))
plt.bar(list(richest['Country/Territory'].value_counts()[0:5].keys()),list(richest['Country/Territory'].value_counts()[0:5]))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(list(richest['Industry'].value_counts()[0:5].keys()),list(richest['Industry'].value_counts()[0:5]))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(list(richest['Age'].value_counts()[0:10].keys()),list(richest['Age'].value_counts()[0:10]))
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(list(richest['Industry'].value_counts()),labels=list(richest['Industry'].value_counts().keys()),autopct='%0.1f%%')
plt.show()
ax.set_title('Industry overview')

# %%
richest.shape
# Out:
# (101, 6)

# %%
text1 = " ".join(source for source in richest.Source)

# %%
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 4000, height = 3000).generate(text1)

# %%
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()
